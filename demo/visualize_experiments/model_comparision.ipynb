# %%
import torch
import matplotlib.pyplot as plt

# %%
epoch_step = 148 # This is roughly one epoch

num_dict = {1: 206, 2: 13, 3:7}

# %%
hist['eval_epoch'][0]
# Out:
# {'loss': 0.029448227087656657,
#  'acc': 0.9125,
#  'acc_w': 0.0593607305936073,
#  'acc_each': {0: 0.0, 1: 1.0, 2: 0.0, 3: 0.0}}

# %%
# Draw the Results:
## resnet50 from scratch:
hist = torch.load("/DKUdata/tangbl/courses/CS302_CV/final_project/src/scanline_traffic_object_detection/ckpt/resnet50_from_scratch/config/hist.pth")
x = list(range(0,len(hist['train_step'])))
step = 1
plt.plot(x[::step], [float(i['loss']) for i in hist['train_step']][::step], linestyle='-', label='loss')
plt.plot(x[::step], [float(i['accuracy']) for i in hist['train_step']][::step], linestyle='-', label='acc')


acc_w_recalculate = [i['acc_each'] for i in hist['eval_epoch']]
res = []
total_num = sum([ 1 / i for i in num_dict.values()])
weights = {k : 1 / i for k, i in num_dict.items()}
for i in acc_w_recalculate:
    avg = 0
    for k, v in num_dict.items():
        avg += weights[k] * i[k]
    avg = avg / total_num
    res.append(avg)

plt.plot(x[::epoch_step], [float(i['acc']) for i in hist['eval_epoch']], linestyle='-', marker='o', label='eval_acc')
plt.plot(x[::epoch_step], res, linestyle='-', marker = 'o', label='eval_acc_weighted')
# plt.legend()
plt.title("resnet50 from scratch")
plt.grid(True)
plt.xlabel("Steps")
plt.legend()
# plt.ylabel("Y-axis")
# Show the plot
plt.show()
# print(sorted([-1])
res_ = max(res)
print(res_)
print(res.index(res_))
print(hist['eval_epoch'][res.index(res_)]['acc_each'])
# Out:
# 0.46214758697322855
# 9
# {0: 0.0, 1: 0.912621359223301, 2: 0.23076923076923078, 3: 0.5714285714285714}

# %%
# Draw the Results:
## resnet50 pretrained:
hist = torch.load("/DKUdata/tangbl/courses/CS302_CV/final_project/src/scanline_traffic_object_detection/ckpt/resnet50_pretrain/config/hist.pth")
x = list(range(0,len(hist['train_step'])))
step = 1
plt.plot(x[::step], [float(i['loss']) for i in hist['train_step']][::step], linestyle='-', label='loss')
plt.plot(x[::step], [float(i['accuracy']) for i in hist['train_step']][::step], linestyle='-', label='acc')

acc_w_recalculate = [i['acc_each'] for i in hist['eval_epoch']]
res = []
total_num = sum([ 1 / i for i in num_dict.values()])
weights = {k : 1 / i for k, i in num_dict.items()}
for i in acc_w_recalculate:
    avg = 0
    for k, v in num_dict.items():
        avg += weights[k] * i[k]
    avg = avg / total_num
    res.append(avg)

plt.plot(x[::epoch_step], [float(i['acc']) for i in hist['eval_epoch']], linestyle='-', marker='o', label='eval_acc')
plt.plot(x[::epoch_step], res, linestyle='-', marker = 'o', label='eval_acc_weighted')
# plt.legend()
plt.title("resnet50 pretrained")
plt.grid(True)
plt.xlabel("Steps")
# plt.legend()
# plt.ylabel("Y-axis")
# Show the plot
plt.show()
# print(sorted([-1])
res_ = max(res)
print(res_)
print(res.index(res_))
print(hist['eval_epoch'][res.index(res_)]['acc_each'])
# Out:
# 0.4869806088989319
# 11
# {0: 0.0, 1: 0.7184466019417476, 2: 0.8461538461538461, 3: 0.2857142857142857}

# %%
# Draw the Results:
## resnet50 transfer:
hist = torch.load("/DKUdata/tangbl/courses/CS302_CV/final_project/src/scanline_traffic_object_detection/ckpt/resnet50_transfer/config/hist.pth")
x = list(range(0,len(hist['train_step'])))
step = 1
plt.plot(x[::step], [float(i['loss']) for i in hist['train_step']][::step], linestyle='-', label='loss')
plt.plot(x[::step], [float(i['accuracy']) for i in hist['train_step']][::step], linestyle='-', label='acc')

acc_w_recalculate = [i['acc_each'] for i in hist['eval_epoch']]
res = []
total_num = sum([ 1 / i for i in num_dict.values()])
weights = {k : 1 / i for k, i in num_dict.items()}
for i in acc_w_recalculate:
    avg = 0
    for k, v in num_dict.items():
        avg += weights[k] * i[k]
    avg = avg / total_num
    res.append(avg)

plt.plot(x[::epoch_step], [float(i['acc']) for i in hist['eval_epoch']], linestyle='-', marker='o', label='eval_acc')
plt.plot(x[::epoch_step], res, linestyle='-', marker = 'o', label='eval_acc_weighted')
# plt.legend()
plt.title("resnet50 tranfer")
plt.grid(True)
plt.xlabel("Steps")
# plt.legend()
# plt.ylabel("Y-axis")
# Show the plot
plt.show()
# print(sorted([-1])
res_ = max(res)
print(res.index(res_))
print(res_)
print(hist['eval_epoch'][res.index(res_)]['acc_each'])
# Out:
# 11
# 0.6546915364425215
# {0: 0.0, 1: 0.7427184466019418, 2: 0.5384615384615384, 3: 0.7142857142857143}

# %%
# Draw the Results:
## mobilenet from scratch:
hist = torch.load("/DKUdata/tangbl/courses/CS302_CV/final_project/src/scanline_traffic_object_detection/ckpt/mobilenet_from_scratch/config/hist.pth")
x = list(range(0,len(hist['train_step'])))
step = 1
plt.plot(x[::step], [float(i['loss']) for i in hist['train_step']][::step], linestyle='-', label='loss')
plt.plot(x[::step], [float(i['accuracy']) for i in hist['train_step']][::step], linestyle='-', label='acc')

acc_w_recalculate = [i['acc_each'] for i in hist['eval_epoch']]
res = []
total_num = sum([ 1 / i for i in num_dict.values()])
weights = {k : 1 / i for k, i in num_dict.items()}
for i in acc_w_recalculate:
    avg = 0
    for k, v in num_dict.items():
        avg += weights[k] * i[k]
    avg = avg / total_num
    res.append(avg)

plt.plot(x[::epoch_step], [float(i['acc']) for i in hist['eval_epoch']], linestyle='-', marker='o', label='eval_acc')
plt.plot(x[::epoch_step], res, linestyle='-', marker = 'o', label='eval_acc_weighted')
# plt.legend()
plt.title("mobilenet from scratch")
plt.grid(True)
plt.xlabel("Steps")
# plt.legend()
# plt.ylabel("Y-axis")
# Show the plot
plt.show()
# print(sorted([-1])
res_ = max(res)
print(res.index(res_))
print(res_)
print(hist['eval_epoch'][res.index(res_)]['acc_each'])
# Out:
# 15
# 0.7103113621098188
# {0: 0.0, 1: 0.8786407766990292, 2: 0.6923076923076923, 3: 0.7142857142857143}

# %%
# Draw the Results:
## mobilenet pretrain:
hist = torch.load("/DKUdata/tangbl/courses/CS302_CV/final_project/src/scanline_traffic_object_detection/ckpt/mobilenet_pretrain/config/hist.pth")
x = list(range(0,len(hist['train_step'])))
step = 1
plt.plot(x[::step], [float(i['loss']) for i in hist['train_step']][::step], linestyle='-', label='loss')
plt.plot(x[::step], [float(i['accuracy']) for i in hist['train_step']][::step], linestyle='-', label='acc')

acc_w_recalculate = [i['acc_each'] for i in hist['eval_epoch']]
res = []
total_num = sum([ 1 / i for i in num_dict.values()])
weights = {k : 1 / i for k, i in num_dict.items()}
for i in acc_w_recalculate:
    avg = 0
    for k, v in num_dict.items():
        avg += weights[k] * i[k]
    avg = avg / total_num
    res.append(avg)

plt.plot(x[::epoch_step], [float(i['acc']) for i in hist['eval_epoch']], linestyle='-', marker='o', label='eval_acc')
plt.plot(x[::epoch_step], res, linestyle='-', marker = 'o', label='eval_acc_weighted')
# plt.legend()
plt.title("mobilenet pretrain")
plt.grid(True)
plt.xlabel("Steps")
# plt.legend()
# plt.ylabel("Y-axis")
# Show the plot
plt.show()
# print(sorted([-1])
res_ = max(res)
print(res.index(res_))
print(res_)
print(hist['eval_epoch'][res.index(res_)]['acc_each'])
# Out:
# 11
# 0.8933760915302554
# {0: 0.0, 1: 0.941747572815534, 2: 0.6923076923076923, 3: 1.0}

# %%
# Draw the Results:
## mobilenet transfer:
hist = torch.load("/DKUdata/tangbl/courses/CS302_CV/final_project/src/scanline_traffic_object_detection/ckpt/mobilenet_transfer/config/hist.pth")
x = list(range(0,len(hist['train_step'])))
step = 1
plt.plot(x[::step], [float(i['loss']) for i in hist['train_step']][::step], linestyle='-', label='loss')
plt.plot(x[::step], [float(i['accuracy']) for i in hist['train_step']][::step], linestyle='-', label='acc')

acc_w_recalculate = [i['acc_each'] for i in hist['eval_epoch']]
res = []
total_num = sum([ 1 / i for i in num_dict.values()])
weights = {k : 1 / i for k, i in num_dict.items()}
for i in acc_w_recalculate:
    avg = 0
    for k, v in num_dict.items():
        avg += weights[k] * i[k]
    avg = avg / total_num
    res.append(avg)

plt.plot(x[::epoch_step], [float(i['acc']) for i in hist['eval_epoch']], linestyle='-', marker='o', label='eval_acc')
plt.plot(x[::epoch_step], res, linestyle='-', marker = 'o', label='eval_acc_weighted')
# plt.legend()
plt.title("mobilenet transfer")
plt.grid(True)
plt.xlabel("Steps")
# plt.legend()
# plt.ylabel("Y-axis")
# Show the plot
plt.show()
# print(sorted([-1])
res_ = max(res)
print(res.index(res_))
print(res_)
print(hist['eval_epoch'][res.index(res_)]['acc_each'])
# Out:
# 6
# 0.6826063525230985
# {0: 0.0, 1: 0.8155339805825242, 2: 0.6153846153846154, 3: 0.7142857142857143}
